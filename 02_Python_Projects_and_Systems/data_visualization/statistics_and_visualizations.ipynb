# %%
# %pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      --------------- ----------------------- 20.5/52.8 kB 65.6 kB/s eta 0:00:01
#      --------------- ----------------------- 20.5/52.8 kB 65.6 kB/s eta 0:00:01
#      ---------------------- ---------------- 30.7/52.8 kB 87.1 kB/s eta 0:00:01
#      ----------------------------- -------- 41.0/52.8 kB 109.3 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 123.8 kB/s eta 0:00:00
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/119.8 kB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
np.array([1,11])
arr=np.array([1,11])
# Out:
# array([ 1, 11])

# %%
fig, ax = plt.subplots()
ax.plot([2,3])
plt.plot([1,2,3,4], [1,4,9,16])

# %%
#sin
x=np.linspace(0,5*np.pi,1000)
y=np.sin(x)
plt.plot(x,y)
plt.plot(x, np.cos(x))
plt.title("Sine wave")

# %%
arr=np.array([-34,1,2,3,12,15,76,20,80])
Q1=np.quantile(arr, 0.25)
Q2=np.quantile(arr, 0.50)
Q3=np.quantile(arr, 0.75)
plt.boxplot(arr)
IQR=Q3-Q1
IQR
upper_bound=Q3+1.5*IQR
lower_bound=Q1-1.5*IQR
upper_bound,lower_bound
# Out:
# (np.float64(47.0), np.float64(-25.0))

# %%
arr[~((arr<lower_bound) | (arr>upper_bound))]
# Out:
# array([ 1,  2,  3, 12, 15, 20])

# %%
#how to find outliers in a dataset using IQR method with defining a function and in result return count of outliers and the outliers themselves and print it in a nice format

def find_outliers_iqr(data):
    Q1 = np.quantile(data, 0.25)
    Q3 = np.quantile(data, 0.75)
    IQR = Q3 - Q1
    upper_bound = Q3 + 1.5 * IQR
    lower_bound = Q1 - 1.5 * IQR
    
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    outlier_count = len(outliers)
    
    print(f"Outliers: {outliers}")
    print(f"Count of outliers: {outlier_count}")
    
    return outliers, outlier_count
# Example usage
data = np.array([-34, 1, 2, 3, 12, 15, 76, 20, 80])
find_outliers_iqr(data)
# Out:
# Outliers: [-34  76  80]
# Count of outliers: 3
# (array([-34,  76,  80]), 3)
